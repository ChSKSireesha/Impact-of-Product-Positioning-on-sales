# %% [markdown]
# ## Import the Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import the Data

# %%
df = pd.read_csv("Product Positioning.csv")

# %%
df.head() # to get the first 5 rows
# Out:
#    Product ID Product Position  Price  Competitor's Price Promotion  \
# 0      185102            Aisle  17.07               16.16        No
# 1      188771            Aisle  17.41               13.13        No
# 2      180176          End-cap  43.16               38.37       Yes
# 3      112917            Aisle  42.26               38.98       Yes
# 4      192936          End-cap  47.94               45.59        No
#
#   Foot Traffic Consumer Demographics Product Category Seasonal  Sales Volume
# 0       Medium              Families         Clothing       No          2823
# 1          Low               Seniors         Clothing       No           654
# 2       Medium          Young adults      Electronics      Yes          2220
# 3          Low              Families         Clothing      Yes          1568
# 4       Medium      College students         Clothing      Yes          2942

# %%
# We can observe product_id,product position,price of the product,competitor's price
#sales volume, seasonal, product category etc

# %%
# If there are any uncessary columns we can remove them before that we need to know how many rows are there
# and how many columns are there

# %%
df.shape # gives rows

# there are 1000 rows and 10 columns
# Out:
# (1000, 10)

# %%
df.columns

# colummns present in the data
# Out:
# Index(['Product ID', 'Product Position', 'Price', 'Competitor's Price',
#        'Promotion', 'Foot Traffic', 'Consumer Demographics',
#        'Product Category', 'Seasonal', 'Sales Volume'],
#       dtype='object')

# %% [markdown]
# ##  Drop the columns if not needed

# %%
# 1 - drop the columns that are not needed 
#df.drop([column_names],axis = 1)
# for the given data set all the columns are required so not dropping any of the columns

# %%
df.info()

# gives the information about the data in the table
# how many non null count is there
# check for null values
# as per the observation there are no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Product ID             1000 non-null   int64
#  1   Product Position       1000 non-null   object
#  2   Price                  1000 non-null   float64
#  3   Competitor's Price     1000 non-null   float64
#  4   Promotion              1000 non-null   object
#  5   Foot Traffic           1000 non-null   object
#  6   Consumer Demographics  1000 non-null   object
#  7   Product Category       1000 non-null   object
#  8   Seasonal               1000 non-null   object
#  9   Sales Volume           1000 non-null   int64
# dtypes: float64(2), int64(2), object(6)
# memory usage: 78.3+ KB

# %% [markdown]
# ##  Drop Duplicate rows if present

# %%
df.drop_duplicates(inplace = True)

# %%
df.count()

# no duplicate rows 
# than check the updated shape

df.shape
# Out:
# (1000, 10)

# %% [markdown]
# ## Rename columns

# %%
#df.rename(columns = {old_column_name:new_column_name,...},inplace = True)

# %% [markdown]
# ## Column Cleaning

# %%
#Product Id

df["Product ID"].unique()
# if there are any strings or / or / null values remove them

#def function(value):
#   if value == "new" | value =="-":
 #       return np.nan
  #  else:
   #     value = str(value).split('/')
    #    value = value[0]
     #   return float(value)
        
# df["column_name"].apply(function)
#df.head()

# if there are null values do imputation techniques
# Out:
# array([185102, 188771, 180176, 112917, 192936, 117590, 189118, 182157,
#        141861, 137121, 113143, 140028, 134693, 151396, 132889, 152174,
#        129906, 195879, 155050, 194410, 141904, 124981, 161909, 129152,
#        183243, 198248, 191230, 187234, 148888, 110805, 179801, 134927,
#        123150, 159145, 172364, 178281, 194339, 174412, 114877, 140727,
#        133109, 127296, 133757, 111760, 198375, 168837, 138505, 116228,
#        167592, 133100, 119955, 189349, 127478, 180661, 186681, 133183,
#        173508, 187930, 124088, 190238, 151925, 163234, 135610, 117065,
#        149315, 149510, 137990, 154016, 117751, 182362, 117725, 145289,
#        173576, 175059, 199368, 162883, 135490, 125408, 134763, 143231,
#        125409, 183074, 147947, 174171, 183064, 177131, 128179, 152723,
#        123824, 166345, 199279, 167981, 146839, 187180, 167640, 165158,
#        111521, 120228, 133078, 137598, 138779, 198329, 110295, 196427,
# ...

# %% [markdown]
# ## Missing Value Imputation

# %%
# checking for missing values
#df.isnull().sum()

#mean imputation
#df["column_name"].fillna(df["column_name"].mean(),inplace = True)

#median imputation
#df["column_name"].fillna(df["column_name"].median(),inplace = True)

#mode imputation
#df["column_name"].fillna(df["column_name"].mode()[0],inplace = True)

#logical imputation
#df["column_name"].fillna(pd.Series(np.random.choice(["column_value1_name","column_value2_name","column_value3_name"], p = [0.60,0.30,0.10], size=len(df))), inplace = True)

# drop null values
# df.dropna(inplace = True)

# %%
# Product Position
df["Product Position"].unique()

# Price
df["Price"].unique()

#Competitor's Price
df["Competitor's Price"].unique()

#Promotion
df["Promotion"].unique()

#Foot Traffic
df["Foot Traffic"].unique()



#Sales Volume
df["Sales Volume"].unique()

# If there are any values to be handled do required techniques and define user defined functions
# Out:
# array([2823,  654, 2220, 1568, 2942, 2968,  952, 2421, 1916,  656, 2663,
#        1260, 2124,  729, 2265, 2226, 2089, 2339, 2321,  669, 1712, 1832,
#        1290, 2356, 1524, 1644,  966, 2575, 2774, 2477, 2608, 2252, 2074,
#        2579, 2931, 1145, 1792, 1796, 1860, 1002, 2063, 1165, 2071, 1474,
#        2202,  665, 2478,  647,  707, 2729, 1590, 1245, 2498, 1041, 1717,
#        2859, 1658,  706, 2065, 1917, 2179, 1633, 1513,  758,  718, 1412,
#        2929, 2366, 2749, 2019, 1506, 1012, 1838, 2170, 1061,  786, 1094,
#        2048, 2578, 2040, 2791, 1249, 2273, 1773, 1733, 2060, 2849, 2277,
#        1135, 1770,  730, 1525, 1017, 1622, 2553, 2347, 2535, 2839, 2801,
#         628, 1448, 1401, 2185, 2135, 1269, 2805, 2133, 1778, 2474, 2032,
#        1659, 2443, 1137, 1847, 2404, 1466, 2328, 1431, 2434, 2067, 2989,
#         743, 2325, 1841, 2231, 2211, 2114, 1350, 2240, 1296,  892, 1678,
#        2016, 1498, 2491, 2556, 2852, 1899, 2466,  818, 1500, 2878, 2386,
# ...

# %%
# drop the columns if they are not necessary

# %%
#Consumer Demographics
df["Consumer Demographics"].unique()

df["Consumer Demographics"].value_counts()
# Out:
# Consumer Demographics
# Families            263
# College students    251
# Seniors             249
# Young adults        237
# Name: count, dtype: int64

# %%
#Product Category
df["Product Category"].unique()

df["Product Category"].value_counts()
# Out:
# Product Category
# Clothing       338
# Electronics    336
# Food           326
# Name: count, dtype: int64

# %%
#Seasonal
df["Seasonal"].unique()

df["Seasonal"].value_counts()

# If the value counts are less than we need to create a user defined function like others

#a = df[df["column_name"]<100]

# def function(value):
#     if (value in a):
 #       return others
  #  else:
     #   return value
    
#df["column_name"] = df["column_name"].apply(function)
# Out:
# Seasonal
# Yes    505
# No     495
# Name: count, dtype: int64

# %% [markdown]
# ## Data is clean, Let's Jump into Visualization

# %%
df.head()
# Out:
#    Product ID Product Position  Price  Competitor's Price Promotion  \
# 0      185102            Aisle  17.07               16.16        No
# 1      188771            Aisle  17.41               13.13        No
# 2      180176          End-cap  43.16               38.37       Yes
# 3      112917            Aisle  42.26               38.98       Yes
# 4      192936          End-cap  47.94               45.59        No
#
#   Foot Traffic Consumer Demographics Product Category Seasonal  Sales Volume
# 0       Medium              Families         Clothing       No          2823
# 1          Low               Seniors         Clothing       No           654
# 2       Medium          Young adults      Electronics      Yes          2220
# 3          Low              Families         Clothing      Yes          1568
# 4       Medium      College students         Clothing      Yes          2942

# %%
# Count of products in each position 

plt.title("Count of products in each position ")
sns.countplot(x = df["Product Position"])
# Out:
# <Axes: title={'center': 'Count of products in each position '}, xlabel='Product Position', ylabel='count'>

# %%
# Count of product category

sns.countplot(x= df["Product Category"])
# Out:
# <Axes: xlabel='Product Category', ylabel='count'>

# %%
# Count of consumer demographics

sns.countplot(x= df["Consumer Demographics"])
# Out:
# <Axes: xlabel='Consumer Demographics', ylabel='count'>

# %%
# Distribution of prices
sns.distplot(x=df["Price"])
# Out:
# C:\Users\SAI SWAROOP\AppData\Local\Temp\ipykernel_28180\2959925614.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df["Price"])
# <Axes: ylabel='Density'>

# %%
# Visualize the distribution of prices and identify outliers.

sns.boxplot(df["Price"])
# no outliers
# Out:
# <Axes: >

# %%
# Proportion of products with and without promotions.
plt.title("Proportion of products with and without promotions")
plt.pie(x = df["Promotion"].value_counts(),autopct = "%.2f%%",labels = df["Promotion"].unique(), radius = 1)
# Out:
# ([<matplotlib.patches.Wedge at 0x23774c31a90>,
# ...
#  [Text(-0.09663630635705894, 1.0957469709260732, 'No'),
#   Text(0.09663630635705882, -1.0957469709260732, 'Yes')],
#  [Text(-0.05271071255839579, 0.5976801659596762, '52.80%'),
#   Text(0.05271071255839571, -0.5976801659596762, '47.20%')])

# %%
#Count of products based on foot traffic levels.

sns.countplot(x=df["Foot Traffic"])
# Out:
# <Axes: xlabel='Foot Traffic', ylabel='count'>

# %%
#Count of products based on seasonal availability.
sns.countplot(x='Seasonal', data=df)
# Out:
# <Axes: xlabel='Seasonal', ylabel='count'>

# %%
#Distribution of sales volume.
sns.distplot(df["Sales Volume"])
# Out:
# C:\Users\SAI SWAROOP\AppData\Local\Temp\ipykernel_28180\2628656374.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Sales Volume"])
# <Axes: xlabel='Sales Volume', ylabel='Density'>

# %%
# Visualize the distribution of sales volume and identify outliers.
sns.boxplot(df["Sales Volume"])
# no outliers
# Out:
# <Axes: >

# %%
#Explore the relationship between price and sales volume.
sns.scatterplot(x=df["Price"],y=df["Sales Volume"])
# Out:
# <Axes: xlabel='Price', ylabel='Sales Volume'>

# %% [markdown]
# ## Identify Outliers and perform outliers technique

# %%
# sns.boxplot(x = df["column_name"])

#df["column_name"].describe()

#Winsorization technique
# find upper limit and lower limit by IQR

#Q3 = df["column_name"].quantile(0.75)
#Q1 = df["column_name"].quantile(0.25)
#IQR = Q3-Q1
#UL = Q3 + 1.5*IQR
#LL = Q1 - 1.5*IQR
#print(LL,UL)

#outlier_data = df[df["column_name"]>UL]
#outlier_data_age_LL = df[df["column_name"]<LL]
#outlier_data

#outlier_data["column_name"].describe()

# fill the outliers with upper and lower limit
#row_index = df["column_name"].index 
#for i in row_index:
 #   if df.loc[i,"column_name"] > UL:
  #      df.loc[i,"column_name"] = UL
   # elif df.loc[i,"column_name"] < LL:
    #    df.loc[i,"column_name"] = LL
    
      
# check again if the outliers are present on the column using boxplot
#sns.boxplot(df["column_name"])

# %%
# Pair plot
sns.pairplot(df)
# Out:
# C:\Users\SAI SWAROOP\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
